# %% [markdown]
# # **Casting e Formattazione**
# Scriviamo un programma che richieda i tuoi dati e li stampi su schermo, i dati che il programma deve richiedere sono:
#
# - Nome e Cognome
# - Anno di nascita
# - Luogo di Nascita
# - Altezza (in metri)
# - Peso (in kilogrammi)
#
# Infine il programma dovrà stampare tutte queste informazione, con altezza e peso arrotondate a 2 cifre dopo la virgola, insieme all'età della persona.
#
# ### **ESEMPIO DI INPUT**
#
# Nome: Giuseppe Gullo
# Anno di nascita: 1938
# Luogi di nascita: Taormina
# Altezza (m): 1.75
# Peso (kg): 71.5
# ### **ESEMPIO DI OUTPUT**
# "Giuseppe Gullo, 81 anni, nato a Taormina nel 1938, altezza: 1.75 m, peso: 71.50 kg"
#
# ## **SUGGERIMENTI**
#
# - La funzione input ritorna sempre una stringa, quindi se vogliamo dei numeri dobbiamo eseguire il casting.
# - Possiamo arrotondare una cifra usando l'operatore di formattazione %.Nf, dove al posto di N dobbiamo inserire il numero di cifre dopo la virgola.
# - Se invece utilizzi il metodo format, puoi arrotondare una cifra usando come placeholder {my_var:.{digits}f} dove my_var è il placeholder della tua variabile e digits è il placeholder per il numero di cifre dopo la virgola.

# %%
# Chiedo in input Nome e Cognome - Anno di nascita - Luogo di Nascita - Altezza (in metri) - Peso (in kilogrammi)
name = input("Come ti chiami? ")
surname = input("Qual'è il tuo cognome? ")
birth_year = int(input("In che anno sei nato? "))
birth_place = input("In che città sei nato? ")
height = float(input("Quanto sei alto (in metri) ? "))
weight = float(input("Quaanto pesi (in chilogrammi?) "))

CURRENT_YEAR = 2026
age = CURRENT_YEAR - birth_year
# Out:
# Come ti chiami? Elisa
# Qual'è il tuo cognome? Re
# In che anno sei nato? 1984
# In che città sei nato? Busto
# Quanto sei alto (in metri) ? 1.58
# Quaanto pesi (in chilogrammi?) 65

# %%
# Stampo le informazioni
print(f"{name} {surname}, {age} anni, nato a {birth_place} nel {birth_year}, altezza: {height:.2f} m, peso: {weight:.2f} kg")
# Out:
# Elisa Re, 42 anni, nato a Busto nel 1984, altezza: 1.58 m, peso: 65.00 kg
