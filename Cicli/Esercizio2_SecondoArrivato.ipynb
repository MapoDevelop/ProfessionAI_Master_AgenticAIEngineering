# %% [markdown]
# # Secondo arrivato

# %%
#punteggi = "2 3 6 6 5"
punteggi = input("Inserisci i punteggi con uno spazio: ")
punteggi = punteggi.split(" ")
print(punteggi)
# Out:
# Inserisci i punteggi con uno spazio: 2 3 6 6 5
# ['2', '3', '6', '6', '5']

# %%
punteggi = set(map(int, punteggi))
punteggi = list(punteggi)
punteggi.sort()

print(punteggi[-2])
# Out:
# 5
